# %%
from nypl import NYPL

nypl = NYPL(response_path='data/responses/nypl_graphql.json', 
            dataframe_path='data/dataframes/nypl.json')

# nypl.store_response()
# nypl.selenium_scrape_unordered_list(headless=True)
# nypl.process_unordered_list()
# nypl.merge_libraries_and_response()
# nypl.selenium_scrape_active_hours(headless=True)
# nypl.process_active_hours()
# nypl.store_dataframe()

nypl.load_data()
nypl.get_df().head()
# Out:
#              id                        name          address_line1  \
# 0  125th-street  125th Street Library 10035  224 East 125th Street
# 1   53rd-street   53rd Street Library 10019    18 West 53rd Street
# 2   58th-street   58th Street Library 10022   127 East 58th Street
# 3   67th-street   67th Street Library 10065   328 East 67th Street
# 4   96th-street   96th Street Library 10128   112 East 96th Street
#
#            address_line2  locality administrative_area  postal_code  \
# 0  224 East 125th Street  New York                  NY        10035
# 1    18 West 53rd Street  New York                  NY        10019
# 2   127 East 58th Street  New York                  NY        10022
# 3   328 East 67th Street  New York                  NY        10065
# 4   112 East 96th Street  New York                  NY        10128
#
#          __typename                                          url  \
# 0  RefineryLocation  https://www.nypl.org/locations/125th-street
# ...

# %%
from queenspl import QueensPL

qpl = QueensPL(response_path='data/responses/queens_location_ajax.json', 
               dataframe_path='data/dataframes/queenspl.json')
qpl.load_data()
qpl.get_df().head()
# Out:
#     branch_name                                           address  \
# 0       Arverne             312 Beach 54 Street Arverne, NY 11692
# 1       Astoria         14-01 Astoria Boulevard Astoria, NY 11102
# 2    Auburndale  25-55 Francis Lewis Boulevard Flushing, NY 11358
# 3  Baisley Park        117-11 Sutphin Boulevard Jamaica, NY 11436
# 4   Bay Terrace            18-36 Bell Boulevard Bayside, NY 11360
#
#             phone                                          image_url  \
# 0  (718) 634-4784  https://www.queenslibrary.org//sites/default/f...
# 1  (718) 278-2220  https://www.queenslibrary.org//sites/default/f...
# 2  (718) 352-2027  https://www.queenslibrary.org//sites/default/f...
# 3  (718) 529-1590  https://www.queenslibrary.org//sites/default/f...
# 4  (718) 423-7004  https://www.queenslibrary.org//sites/default/f...
#
#                                                 link  Sunday  \
# 0  https://www.queenslibrary.org//about-us/locati...  Closed
# ...
