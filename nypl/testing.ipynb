# %%
import json
import pandas as pd

with open('data/nypl_all.json', 'r') as file:
    data = json.load(file)
df = pd.DataFrame(data)

# %%
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from tqdm import tqdm

headless = False
# Initialize Edge driver
if headless:
    options = Options()
    options.add_argument("--headless=new")  # Use "--headless=new" for newer Edge versions
    driver = webdriver.Edge(options=options)
else:
    driver = webdriver.Edge()
wait = WebDriverWait(driver, 10)

unable_to_scrape = []
library_hours = {}

# Wrap the main scraping loop with tqdm progress bar
for id, url in tqdm(df[['id', 'URL']].values.tolist()[0:10], desc='Scraping library pages'):
    driver.get(url)
    try:
        condition = EC.any_of(
            EC.visibility_of_element_located((By.XPATH, "//h2[text()='Regular Hours']")),
            EC.visibility_of_element_located((By.XPATH, "//p[@data-testid='ds-text' and contains(text(), 'Temporarily Closed')]")),
            EC.visibility_of_element_located((By.XPATH, "//button[@id='tabs--r59kd5t6---tab-1' and normalize-space(text())='Upcoming Hours']"))
        )
        header_element = wait.until(condition)

        if header_element.text.strip() == 'Regular Hours':
            parent_div = header_element.find_element(By.XPATH, "./following-sibling::table[1]")
            rows = parent_div.find_elements(By.TAG_NAME, 'tr')

            hours_data = {}
            for row in rows[1:]:
                cols = row.find_elements(By.TAG_NAME, 'th') + row.find_elements(By.TAG_NAME, 'td')
                day = cols[0].text if len(cols) > 0 else ''
                hours = cols[1].text if len(cols) > 1 else ''
                hours_data[day] = hours
            library_hours[id] = hours_data
        
        elif header_element.text.strip() == 'Temporarily Closed':
            library_hours[id] = {'Monday': 'Temporarily Closed', 'Tuesday': 'Temporarily Closed', 'Wednesday': 'Temporarily Closed',
                                 'Thursday': 'Temporarily Closed', 'Friday': 'Temporarily Closed', 'Saturday': 'Temporarily Closed',
                                 'Sunday': 'Temporarily Closed'}
        
        elif header_element.text.strip() == 'Upcoming Hours':
            upcoming_tab_panel = wait.until(
                EC.visibility_of_element_located((By.ID, "tabs--r59kd5t6---tabpanel-1"))
            )
            table = upcoming_tab_panel.find_element(By.CSS_SELECTOR, "table.css-fvtdov")
            rows = table.find_elements(By.CSS_SELECTOR, "tbody tr")
            schedule_data = {}
            for row in rows:
                day = row.find_element(By.CSS_SELECTOR, "th p[data-testid='ds-text']").text.strip()
                date = row.find_element(By.CSS_SELECTOR, "td:nth-of-type(1) p[data-testid='ds-text']").text.strip()
                hours = row.find_element(By.CSS_SELECTOR, "td:nth-of-type(2) p[data-testid='ds-text']").text.strip()
                schedule_data[day] = hours
            library_hours[id] = schedule_data

    except Exception:
        unable_to_scrape.append(url)

driver.quit()
# Out:
# Scraping library pages: 100%|██████████| 10/10 [00:25<00:00,  2.52s/it]

# %%
unable_to_scrape
# Out:
# []

# %%
library_hours
# Out:
# {'125th-street': {'Monday': '11 AM–7 PM',
#   'Tuesday': '10 AM–6 PM',
#   'Wednesday': '10 AM–6 PM',
#   'Thursday': '11 AM–7 PM',
#   'Friday': '10 AM–5 PM',
#   'Saturday': '10 AM–5 PM',
#   'Sunday': 'Closed'},
#  '53rd-street': {'Monday': '11 AM–6 PM',
#   'Tuesday': '11 AM–6 PM',
#   'Wednesday': '11 AM–6 PM',
#   'Thursday': '11 AM–6 PM',
#   'Friday': '11 AM–6 PM',
#   'Saturday': '11 AM–6 PM',
#   'Sunday': 'Closed'},
#  '58th-street': {'Monday': '10 AM–6 PM',
#   'Tuesday': '10 AM–6 PM',
#   'Wednesday': '10 AM–6 PM',
#   'Thursday': '10 AM–6 PM',
#   'Friday': '10 AM–5 PM',
#   'Saturday': '10 AM–5 PM',
#   'Sunday': 'Closed'},
#  '67th-street': {'Monday': '11 AM–7 PM',
#   'Tuesday': '11 AM–7 PM',
#   'Wednesday': '11 AM–7 PM',
#   'Thursday': '11 AM–7 PM',
#   'Friday': '10 AM–5 PM',
#   'Saturday': '10 AM–5 PM',
#   'Sunday': 'Closed'},
#  '96th-street': {'Monday': '10 AM–7 PM',
#   'Tuesday': '10 AM–7 PM',
#   'Wednesday': 'CLOSED',
#   'Thursday': '10 AM–7 PM',
#   'Friday': '10 AM–5 PM',
#   'Saturday': '10 AM–5 PM',
#   'Sunday': 'CLOSED'},
#  'aguilar': {'Monday': 'Temporarily Closed',
#   'Tuesday': 'Temporarily Closed',
#   'Wednesday': 'Temporarily Closed',
#   'Thursday': 'Temporarily Closed',
#   'Friday': 'Temporarily Closed',
#   'Saturday': 'Temporarily Closed',
#   'Sunday': 'Temporarily Closed'},
#  'allerton': {'Monday': '10 AM–6 PM',
#   'Tuesday': '10 AM–6 PM',
#   'Wednesday': '10 AM–6 PM',
#   'Thursday': '10 AM–6 PM',
#   'Friday': '10 AM–6 PM',
#   'Saturday': '10 AM–5 PM',
#   'Sunday': 'Closed'},
#  'heiskell': {'Monday': '10 AM–5 PM',
#   'Tuesday': '12 PM–7 PM',
#   'Wednesday': '10 AM–5 PM',
#   'Thursday': '12 PM–7 PM',
#   'Friday': '10 AM–5 PM',
#   'Saturday': '10 AM–5 PM',
#   'Sunday': 'Closed'},
#  'art-architecture-collection': {'Monday': '10 AM–5:45 PM',
#   'Tuesday': '10 AM–7:45 PM',
#   'Wednesday': '10 AM–7:45 PM',
#   'Thursday': '10 AM–5:45 PM',
#   'Friday': '10 AM–5:45 PM',
#   'Saturday': '10 AM–5:45 PM',
#   'Sunday': '1 PM–4:45 PM'},
#  'art-and-artifacts-division': {'Monday': '10 AM–5 PM',
#   'Tuesday': '10 AM–5 PM',
#   'Wednesday': '10 AM–5 PM',
#   'Thursday': '10 AM–5 PM',
#   'Friday': '10 AM–5 PM',
#   'Saturday': 'Closed',
#   'Sunday': 'Closed'}}

# %%
df
# Out:
#                      id                              name  \
# 0          125th-street        125th Street Library 10035
# 1           53rd-street         53rd Street Library 10019
# 2           58th-street         58th Street Library 10022
# 3           67th-street         67th Street Library 10065
# 4           96th-street         96th Street Library 10128
# ..                  ...                               ...
# 123   west-new-brighton   West New Brighton Library 10310
# 124  westchester-square  Westchester Square Library 10461
# 125    woodlawn-heights    Woodlawn Heights Library 10470
# 126           woodstock           Woodstock Library 10456
# 127           yorkville           Yorkville Library 10075
#
#              address_line1          address_line2       locality  \
# 0    224 East 125th Street  224 East 125th Street       New York
# 1      18 West 53rd Street    18 West 53rd Street       New York
# 2     127 East 58th Street   127 East 58th Street       New York
# 3     328 East 67th Street   328 East 67th Street       New York
# 4     112 East 96th Street   112 East 96th Street       New York
# ..                     ...                    ...            ...
# 123   976 Castleton Avenue   976 Castleton Avenue  Staten Island
# 124      2521 Glebe Avenue      2521 Glebe Avenue          Bronx
# 125    4355 Katonah Avenue    4355 Katonah Avenue          Bronx
# 126  761 East 160th Street  761 East 160th Street          Bronx
# 127   222 East 79th Street   222 East 79th Street       New York
#
#     administrative_area postal_code        __typename  \
# 0                    NY       10035  RefineryLocation
# 1                    NY       10019  RefineryLocation
# 2                    NY       10022  RefineryLocation
# 3                    NY       10065  RefineryLocation
# 4                    NY       10128  RefineryLocation
# ..                  ...         ...               ...
# 123                  NY       10310  RefineryLocation
# 124                  NY       10461  RefineryLocation
# 125                  NY       10470  RefineryLocation
# 126                  NY       10456  RefineryLocation
# 127                  NY       10075  RefineryLocation
#
#                                  Name  \
# 0          125th Street Library 10035
# 1           53rd Street Library 10019
# 2           58th Street Library 10022
# 3           67th Street Library 10065
# 4           96th Street Library 10128
# ..                                ...
# 123   West New Brighton Library 10310
# 124  Westchester Square Library 10461
# 125    Woodlawn Heights Library 10470
# 126           Woodstock Library 10456
# 127           Yorkville Library 10075
#
#                                                    URL  \
# 0          https://www.nypl.org/locations/125th-street
# 1           https://www.nypl.org/locations/53rd-street
# 2           https://www.nypl.org/locations/58th-street
# 3           https://www.nypl.org/locations/67th-street
# 4           https://www.nypl.org/locations/96th-street
# ..                                                 ...
# 123   https://www.nypl.org/locations/west-new-brighton
# 124  https://www.nypl.org/locations/westchester-square
# 125    https://www.nypl.org/locations/woodlawn-heights
# 126           https://www.nypl.org/locations/woodstock
# 127           https://www.nypl.org/locations/yorkville
#
#                                            Address    Zip         Phone  \
# 0        224 East 125th Street\nNew York, NY 10035  10035  212-534-5050
# 1          18 West 53rd Street\nNew York, NY 10019  10019  212-714-8400
# 2         127 East 58th Street\nNew York, NY 10022  10022  212-759-7358
# 3         328 East 67th Street\nNew York, NY 10065  10065  212-734-1717
# 4         112 East 96th Street\nNew York, NY 10128  10128  212-289-0908
# ..                                             ...    ...           ...
# 123  976 Castleton Avenue\nStaten Island, NY 10310  10310  718-442-1416
# 124             2521 Glebe Avenue\nBronx, NY 10461  10461  718-863-0436
# 125           4355 Katonah Avenue\nBronx, NY 10470  10470  718-519-9627
# 126         761 East 160th Street\nBronx, NY 10456  10456  718-665-6255
# 127       222 East 79th Street\nNew York, NY 10075  10075  212-744-5824
#
#                                          Accessibility Todays Hours  \
# 0                                     Fully Accessible         None
# 1                                     Fully Accessible         None
# 2    Partially Accessible : All parts of the librar...         None
# 3                                     Fully Accessible         None
# 4                                     Fully Accessible         None
# ..                                                 ...          ...
# 123                                   Fully Accessible         None
# 124                                     Today's Hours:         None
# 125                                   Fully Accessible         None
# 126                                   Fully Accessible         None
# 127                                     Today's Hours:         None
#
#                                               Map Link
# 0    http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 1    http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 2    http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 3    http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 4    http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# ..                                                 ...
# 123  http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 124  http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 125  http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 126  http://maps.google.com/maps?f=q&hl=en&saddr=&d...
# 127  http://maps.google.com/maps?f=q&hl=en&saddr=&d...
#
# [128 rows x 16 columns]

# %%
for id, hours in library_hours.items():
    for day_of_week in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']:
        df.loc[df['id'] == id, day_of_week] = hours[day_of_week]

# %%
df.to_excel('data.xlsx', index=False)

# %%
import os
os.startfile('data.xlsx')

# %%
# df.to_json('data/data.json', orient="records", indent=4)
